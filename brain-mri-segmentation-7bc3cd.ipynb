# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob

import time

# %matplotlib inline
from IPython.display import Image, display
from skimage import io

import tensorflow as tf
from skimage.color import rgb2gray
from tensorflow.keras import layers, optimizers
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.models import Model,Sequential, load_model, save_model
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint,LearningRateScheduler
from tensorflow.keras.layers import Input, Activation, BatchNormalization, Dropout, Lambda, Conv2D, Conv2DTranspose, MaxPooling2D, concatenate, UpSampling2D
from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.model_selection import train_test_split
import cv2
from sklearn.preprocessing import StandardScaler, normalize

# %%
data_path = []
for sub_dir_path in glob.glob("/kaggle/input/lgg-mri-segmentation/kaggle_3m/"+"*"):
    try:
        dir_name = sub_dir_path.split('/')[-1]
        for filename in os.listdir(sub_dir_path):
            mask_path = sub_dir_path + '/' + filename
            data_path.extend([dir_name, mask_path])
    except Exception as e:
        print(e)
# Out:
# [Errno 20] Not a directory: '/kaggle/input/lgg-mri-segmentation/kaggle_3m/README.md'
# [Errno 20] Not a directory: '/kaggle/input/lgg-mri-segmentation/kaggle_3m/data.csv'

# %%
filenames = data_path[::2]
masks = data_path[1::2]

# %%
df = pd.DataFrame(data={"patient_id": filenames,"img_path": masks})

# %%
original_img     = df[~df['img_path'].str.contains("mask")]
mask_img = df[df['img_path'].str.contains("mask")]

# %%
imgs = sorted(original_img["img_path"].values, key=lambda x : int(x[89:-4]))
masks = sorted(mask_img["img_path"].values, key=lambda x : int(x[89:-9]))

# %%
mri_df = pd.DataFrame({"patient_id": original_img.patient_id.values,"img_path": imgs,
                           'mask_path':masks})
mri_df.head()
# Out:
#               patient_id                                           img_path  \
# 0  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#                                            mask_path
# 0  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...

# %%
def get_diagnosis(img_path):
    value = np.max(cv2.imread(img_path))
    if value > 0 : 
        return 1
    else:
        return 0

# %%
mri_df['mask'] = mri_df['mask_path'].apply(lambda x: get_diagnosis(x))

mri_df['mask_path'] = mri_df['mask_path'].apply(lambda x: str(x))
mri_df.head()
# Out:
#               patient_id                                           img_path  \
# 0  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#                                            mask_path  mask
# 0  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 1  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 2  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 4  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0

# %%
mri_df.drop(columns=['patient_id'],inplace=True)

# %%
mri_train, mri_test = train_test_split(mri_df,test_size = 0.1)
mri_train, mri_val = train_test_split(mri_train,test_size = 0.2)

print('Training data shape is {0}'.format(mri_train.values.shape))
print('Test data shape is {0}'.format(mri_test.values.shape))
mri_train.sample(n=5)
# Out:
# Training data shape is (2828, 3)
# Test data shape is (393, 3)
#                                                img_path  \
# 1766  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3896  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 495   /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3102  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1540  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#                                               mask_path  mask
# 1766  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3896  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 495   /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3102  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     1
# 1540  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0

# %%
count = 0
i = 0
fig,axs = plt.subplots(3,3, figsize=(20,15))
for mask in mri_df['mask']:
    if (mask==1):
        img = io.imread(mri_df.img_path[i])
        axs[count][0].title.set_text("Brain MRI")
        axs[count][0].imshow(img)
        
        mask = io.imread(mri_df.mask_path[i])
        axs[count][1].title.set_text("Mask =" + str(mri_df['mask'][i]))
        axs[count][1].imshow(mask, cmap='gray')
        
        img[mask==255] = (255,0,0)  # change pixel color at the position of mask
        axs[count][2].title.set_text("MRI with Mask =" + str(mri_df['mask'][i]))
        axs[count][2].imshow(img)
        count +=1
    i += 1
    if (count==3):
        break
        
fig.tight_layout()

# %%
def train_generator(data_frame, batch_size, aug_dict,
        image_color_mode="rgb",
        mask_color_mode="grayscale",
        image_save_prefix="image",
        mask_save_prefix="mask",
        save_to_dir=None,
        target_size=(256,256),
        seed=1):

    image_datagen = ImageDataGenerator(**aug_dict)
    mask_datagen = ImageDataGenerator(**aug_dict)
    
    image_generator = image_datagen.flow_from_dataframe(
        data_frame,
        x_col = "img_path",
        class_mode = None,
        color_mode = image_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = image_save_prefix,
        seed = seed)

    mask_generator = mask_datagen.flow_from_dataframe(
        data_frame,
        x_col = "mask_path",
        class_mode = None,
        color_mode = mask_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = mask_save_prefix,
        seed = seed)

    train_gen = zip(image_generator, mask_generator)
    
    for (img, mask) in train_gen:
        img, mask = adjust_data(img, mask)
        yield (img,mask)

# %%
def adjust_data(img,mask):
    img = img / 255
    mask = mask / 255
    mask[mask > 0.5] = 1
    mask[mask <= 0.5] = 0
    
    return (img, mask)

# %%
train_generator_args = dict(rotation_range=0.2,
                            width_shift_range=0.05,
                            height_shift_range=0.05,
                            shear_range=0.05,
                            zoom_range=0.05,
                            horizontal_flip=True,
                            fill_mode='nearest')

train_gen = train_generator(mri_train, 32,
                                train_generator_args,
                                target_size=(256, 256))
    
val_gen = train_generator(mri_val, 32,
                                dict(),
                                target_size=(256, 256))

# %%
def unet(pretrained_weights = None,input_size = (256,256,3)):
    inputs = Input(input_size)
    conv1 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(inputs)
    conv1 = Conv2D(64, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv1)
    bn_1 = BatchNormalization(axis=3)(conv1)
    act_1 = Activation('relu')(bn_1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(act_1)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2 = Conv2D(128, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv2)
    bn_2 = BatchNormalization(axis=3)(conv2)
    act_2 = Activation('relu')(bn_2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(act_2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3 = Conv2D(256, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv3)
    bn_3 = BatchNormalization(axis=3)(conv3)
    act_3 = Activation('relu')(bn_3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(act_3)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4 = Conv2D(512, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv4)
    bn_4 = BatchNormalization(axis=3)(conv4)
    act_4 = Activation('relu')(bn_4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(act_4)

    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool4)
    conv5 = Conv2D(1024, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv5)
    bn_5 = BatchNormalization(axis=3)(conv5)
    act_5 = Activation('relu')(bn_5)

    up6 = Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(act_5))
    merge6 = concatenate([conv4,up6], axis = 3)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6 = Conv2D(512, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv6)
    bn_6 = BatchNormalization(axis=3)(conv6)
    act_6 = Activation('relu')(bn_6)
    
    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(act_6))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = Conv2D(256, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv7)
    bn_7 = BatchNormalization(axis=3)(conv7)
    act_7 = Activation('relu')(bn_7)

    
    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(act_7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = Conv2D(128, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv8)
    bn_8 = BatchNormalization(axis=3)(conv8)
    act_8 = Activation('relu')(bn_8)
    
    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(act_8))
    merge9 = concatenate([conv1,up9], axis = 3)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv9 = Conv2D(2, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv9)
    bn_9 = BatchNormalization(axis=3)(conv9)
    act_9 = Activation('relu')(bn_9)
    
    conv10 = Conv2D(1, 1, activation = 'sigmoid')(act_9)

    model = model = Model(inputs=[inputs] , outputs = [conv10])    
    return model

# %%
model = unet()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 64) 36928       conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 64) 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 256, 256, 64) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 64) 0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 128 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 128 147584      conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128, 128, 128 512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 128, 128, 128 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 256)  295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 256)  590080      conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64, 64, 256)  1024        conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 64, 64, 256)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 256)  0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 512)  1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 512)  2359808     conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 512)  2048        conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 512)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 512)  0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 1024) 4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 1024) 9438208     conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 1024) 4096        conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 16, 16, 1024) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 32, 32, 1024) 0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 512)  2097664     up_sampling2d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 1024) 0           conv2d_7[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 512)  4719104     concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 512)  2359808     conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 512)  2048        conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 512)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 512)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 256)  524544      up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 512)  0           conv2d_5[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 256)  1179904     concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 256)  590080      conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 64, 64, 256)  1024        conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 64, 64, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 256 0           activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 128 131200      up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 256 0           conv2d_3[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 128 295040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 128, 128 147584      conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 128, 128, 128 512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 128, 128, 128 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 256, 256, 128 0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 256, 256, 64) 32832       up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 128 0           conv2d_1[0][0]
#                                                                  conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 256, 256, 64) 73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 256, 256, 64) 36928       conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 256, 256, 2)  1154        conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 256, 256, 2)  8           conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 256, 256, 2)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 256, 256, 1)  3           activation_8[0][0]
# ==================================================================================================
# Total params: 31,044,365
# Trainable params: 31,038,601
# Non-trainable params: 5,764
# __________________________________________________________________________________________________

# %%
lr_reduction = ReduceLROnPlateau(monitor='val_iou',patience=8, verbose=1,
                                 factor=0.4, min_lr=0.0001)

early_stop = EarlyStopping(monitor='val_iou', min_delta=0.00001, patience=6, 
                           mode='auto', restore_best_weights=True)

model_checkpoint = ModelCheckpoint('unet_membrane.hdf5', verbose=1,monitor='val_iou',
                                   save_best_only=True)

# %%
smooth =100
def iou(y_true, y_pred):
    intersection = K.sum(y_true * y_pred)
    sum_ = K.sum(y_true + y_pred)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

# %%
def dice_coef(y_true, y_pred):
    y_truef=K.flatten(y_true)
    y_predf=K.flatten(y_pred)
    And=K.sum(y_truef* y_predf)
    return((2* And + smooth) / (K.sum(y_truef) + K.sum(y_predf) + smooth))

def dice_coef_loss(y_true, y_pred):
    return 1-dice_coef(y_true, y_pred)

# %%
EPOCH = 70
learning_rate = 1e-3

# %%
model.compile(optimizer=optimizers.Adam(learning_rate=1e-3, beta_1=0.9, beta_2=0.999, epsilon=None, decay=1e-3/32, amsgrad=False), 
              loss=dice_coef_loss, metrics=["binary_accuracy", iou, dice_coef])

# %%
history = model.fit(train_gen,steps_per_epoch=len(mri_train)/32,
                    epochs=EPOCH ,validation_data=val_gen,validation_steps=len(mri_val) / 32,
                    callbacks=[model_checkpoint])
# Out:
# Found 2828 validated image filenames.
# Found 2828 validated image filenames.
# Epoch 1/70
# 89/88 [==============================] - ETA: 0s - loss: 0.9596 - binary_accuracy: 0.8976 - iou: 0.0208 - dice_coef: 0.0405Found 708 validated image filenames.
# Found 708 validated image filenames.
# 88/88 [==============================] - 143s 1s/step - loss: 0.9596 - binary_accuracy: 0.8976 - iou: 0.0208 - dice_coef: 0.0405 - val_loss: 0.9665 - val_binary_accuracy: 0.9891 - val_iou: 0.0172 - val_dice_coef: 0.0337
#
# Epoch 00001: val_iou improved from inf to 0.01725, saving model to unet_membrane.hdf5
# Epoch 2/70
# 88/88 [==============================] - 101s 1s/step - loss: 0.9525 - binary_accuracy: 0.9478 - iou: 0.0245 - dice_coef: 0.0476 - val_loss: 0.9460 - val_binary_accuracy: 0.9466 - val_iou: 0.0272 - val_dice_coef: 0.0526
#
# Epoch 00002: val_iou did not improve from 0.01725
# Epoch 3/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.9457 - binary_accuracy: 0.9564 - iou: 0.0280 - dice_coef: 0.0542 - val_loss: 0.9147 - val_binary_accuracy: 0.8901 - val_iou: 0.0471 - val_dice_coef: 0.0893
#
# Epoch 00003: val_iou did not improve from 0.01725
# Epoch 4/70
# 88/88 [==============================] - 103s 1s/step - loss: 0.9328 - binary_accuracy: 0.9667 - iou: 0.0348 - dice_coef: 0.0668 - val_loss: 0.9556 - val_binary_accuracy: 0.9774 - val_iou: 0.0228 - val_dice_coef: 0.0443
#
# Epoch 00004: val_iou did not improve from 0.01725
# Epoch 5/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.9165 - binary_accuracy: 0.9729 - iou: 0.0438 - dice_coef: 0.0833 - val_loss: 0.9301 - val_binary_accuracy: 0.9908 - val_iou: 0.0365 - val_dice_coef: 0.0698
#
# Epoch 00005: val_iou did not improve from 0.01725
# Epoch 6/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.8941 - binary_accuracy: 0.9735 - iou: 0.0561 - dice_coef: 0.1053 - val_loss: 0.8790 - val_binary_accuracy: 0.9441 - val_iou: 0.0635 - val_dice_coef: 0.1185
#
# Epoch 00006: val_iou did not improve from 0.01725
# Epoch 7/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.8510 - binary_accuracy: 0.9830 - iou: 0.0817 - dice_coef: 0.1495 - val_loss: 0.8184 - val_binary_accuracy: 0.9846 - val_iou: 0.0973 - val_dice_coef: 0.1749
#
# Epoch 00007: val_iou did not improve from 0.01725
# Epoch 8/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.9558 - binary_accuracy: 0.9365 - iou: 0.0228 - dice_coef: 0.0441 - val_loss: 0.9147 - val_binary_accuracy: 0.8120 - val_iou: 0.0465 - val_dice_coef: 0.0881
#
# Epoch 00008: val_iou did not improve from 0.01725
# Epoch 9/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.8127 - binary_accuracy: 0.9682 - iou: 0.1052 - dice_coef: 0.1877 - val_loss: 0.6841 - val_binary_accuracy: 0.9885 - val_iou: 0.1854 - val_dice_coef: 0.3087
#
# Epoch 00009: val_iou did not improve from 0.01725
# Epoch 10/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.6844 - binary_accuracy: 0.9896 - iou: 0.1910 - dice_coef: 0.3158 - val_loss: 0.8958 - val_binary_accuracy: 0.8946 - val_iou: 0.0540 - val_dice_coef: 0.1016
#
# Epoch 00010: val_iou did not improve from 0.01725
# Epoch 11/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.5690 - binary_accuracy: 0.9922 - iou: 0.2823 - dice_coef: 0.4321 - val_loss: 0.5435 - val_binary_accuracy: 0.9855 - val_iou: 0.2974 - val_dice_coef: 0.4525
#
# Epoch 00011: val_iou did not improve from 0.01725
# Epoch 12/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.4861 - binary_accuracy: 0.9926 - iou: 0.3520 - dice_coef: 0.5114 - val_loss: 0.4498 - val_binary_accuracy: 0.9906 - val_iou: 0.3792 - val_dice_coef: 0.5456
#
# Epoch 00012: val_iou did not improve from 0.01725
# Epoch 13/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.4060 - binary_accuracy: 0.9939 - iou: 0.4289 - dice_coef: 0.5931 - val_loss: 0.5359 - val_binary_accuracy: 0.9843 - val_iou: 0.3153 - val_dice_coef: 0.4723
#
# Epoch 00013: val_iou did not improve from 0.01725
# Epoch 14/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.3587 - binary_accuracy: 0.9944 - iou: 0.4793 - dice_coef: 0.6377 - val_loss: 0.3247 - val_binary_accuracy: 0.9948 - val_iou: 0.5013 - val_dice_coef: 0.6536
#
# Epoch 00014: val_iou did not improve from 0.01725
# Epoch 15/70
# 88/88 [==============================] - 101s 1s/step - loss: 0.3133 - binary_accuracy: 0.9949 - iou: 0.5315 - dice_coef: 0.6870 - val_loss: 0.3119 - val_binary_accuracy: 0.9951 - val_iou: 0.5386 - val_dice_coef: 0.6928
#
# Epoch 00015: val_iou did not improve from 0.01725
# Epoch 16/70
# 88/88 [==============================] - 103s 1s/step - loss: 0.2920 - binary_accuracy: 0.9951 - iou: 0.5551 - dice_coef: 0.7085 - val_loss: 0.2786 - val_binary_accuracy: 0.9959 - val_iou: 0.5579 - val_dice_coef: 0.7043
#
# Epoch 00016: val_iou did not improve from 0.01725
# Epoch 17/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.2922 - binary_accuracy: 0.9949 - iou: 0.5568 - dice_coef: 0.7083 - val_loss: 0.4474 - val_binary_accuracy: 0.9941 - val_iou: 0.3876 - val_dice_coef: 0.5345
#
# Epoch 00017: val_iou did not improve from 0.01725
# Epoch 18/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.2734 - binary_accuracy: 0.9953 - iou: 0.5805 - dice_coef: 0.7273 - val_loss: 0.2570 - val_binary_accuracy: 0.9957 - val_iou: 0.5912 - val_dice_coef: 0.7392
#
# Epoch 00018: val_iou did not improve from 0.01725
# Epoch 19/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.2620 - binary_accuracy: 0.9955 - iou: 0.5948 - dice_coef: 0.7388 - val_loss: 0.2922 - val_binary_accuracy: 0.9954 - val_iou: 0.5680 - val_dice_coef: 0.7156
#
# Epoch 00019: val_iou did not improve from 0.01725
# Epoch 20/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.2516 - binary_accuracy: 0.9955 - iou: 0.6105 - dice_coef: 0.7493 - val_loss: 0.2156 - val_binary_accuracy: 0.9960 - val_iou: 0.6582 - val_dice_coef: 0.7899
#
# Epoch 00020: val_iou did not improve from 0.01725
# Epoch 21/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.2172 - binary_accuracy: 0.9961 - iou: 0.6460 - dice_coef: 0.7799 - val_loss: 0.3035 - val_binary_accuracy: 0.9955 - val_iou: 0.5466 - val_dice_coef: 0.7005
#
# Epoch 00021: val_iou did not improve from 0.01725
# Epoch 22/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.2115 - binary_accuracy: 0.9961 - iou: 0.6560 - dice_coef: 0.7886 - val_loss: 0.2218 - val_binary_accuracy: 0.9961 - val_iou: 0.6468 - val_dice_coef: 0.7829
#
# Epoch 00022: val_iou did not improve from 0.01725
# Epoch 23/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.1940 - binary_accuracy: 0.9964 - iou: 0.6785 - dice_coef: 0.8055 - val_loss: 0.1937 - val_binary_accuracy: 0.9965 - val_iou: 0.6811 - val_dice_coef: 0.8080
#
# Epoch 00023: val_iou did not improve from 0.01725
# Epoch 24/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.9396 - binary_accuracy: 0.9676 - iou: 0.0324 - dice_coef: 0.0600 - val_loss: 0.7751 - val_binary_accuracy: 0.9373 - val_iou: 0.1325 - val_dice_coef: 0.2302
#
# Epoch 00024: val_iou did not improve from 0.01725
# Epoch 25/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.2669 - binary_accuracy: 0.9922 - iou: 0.6020 - dice_coef: 0.7342 - val_loss: 0.2316 - val_binary_accuracy: 0.9960 - val_iou: 0.6270 - val_dice_coef: 0.7652
#
# Epoch 00025: val_iou did not improve from 0.01725
# Epoch 26/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.2069 - binary_accuracy: 0.9962 - iou: 0.6652 - dice_coef: 0.7931 - val_loss: 0.1800 - val_binary_accuracy: 0.9967 - val_iou: 0.6825 - val_dice_coef: 0.7966
#
# Epoch 00026: val_iou did not improve from 0.01725
# Epoch 27/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.1843 - binary_accuracy: 0.9964 - iou: 0.6943 - dice_coef: 0.8145 - val_loss: 0.1995 - val_binary_accuracy: 0.9966 - val_iou: 0.6707 - val_dice_coef: 0.7994
#
# Epoch 00027: val_iou did not improve from 0.01725
# Epoch 28/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.1904 - binary_accuracy: 0.9965 - iou: 0.6900 - dice_coef: 0.8102 - val_loss: 0.2001 - val_binary_accuracy: 0.9967 - val_iou: 0.6815 - val_dice_coef: 0.7962
#
# Epoch 00028: val_iou did not improve from 0.01725
# Epoch 29/70
# 88/88 [==============================] - 103s 1s/step - loss: 0.1837 - binary_accuracy: 0.9965 - iou: 0.6962 - dice_coef: 0.8158 - val_loss: 0.1605 - val_binary_accuracy: 0.9972 - val_iou: 0.7273 - val_dice_coef: 0.8351
#
# Epoch 00029: val_iou did not improve from 0.01725
# Epoch 30/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.1830 - binary_accuracy: 0.9966 - iou: 0.7011 - dice_coef: 0.8176 - val_loss: 0.1670 - val_binary_accuracy: 0.9967 - val_iou: 0.7191 - val_dice_coef: 0.8344
#
# Epoch 00030: val_iou did not improve from 0.01725
# Epoch 31/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.1680 - binary_accuracy: 0.9968 - iou: 0.7199 - dice_coef: 0.8321 - val_loss: 0.2006 - val_binary_accuracy: 0.9959 - val_iou: 0.6721 - val_dice_coef: 0.7989
#
# Epoch 00031: val_iou did not improve from 0.01725
# Epoch 32/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.1878 - binary_accuracy: 0.9965 - iou: 0.6904 - dice_coef: 0.8119 - val_loss: 0.1822 - val_binary_accuracy: 0.9969 - val_iou: 0.7014 - val_dice_coef: 0.8164
#
# Epoch 00032: val_iou did not improve from 0.01725
# Epoch 33/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.1851 - binary_accuracy: 0.9965 - iou: 0.6942 - dice_coef: 0.8154 - val_loss: 0.1612 - val_binary_accuracy: 0.9968 - val_iou: 0.7290 - val_dice_coef: 0.8372
#
# Epoch 00033: val_iou did not improve from 0.01725
# Epoch 34/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.1579 - binary_accuracy: 0.9969 - iou: 0.7303 - dice_coef: 0.8411 - val_loss: 0.1388 - val_binary_accuracy: 0.9975 - val_iou: 0.7419 - val_dice_coef: 0.8436
#
# Epoch 00034: val_iou did not improve from 0.01725
# Epoch 35/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.1552 - binary_accuracy: 0.9971 - iou: 0.7341 - dice_coef: 0.8414 - val_loss: 0.1738 - val_binary_accuracy: 0.9970 - val_iou: 0.7079 - val_dice_coef: 0.8254
#
# Epoch 00035: val_iou did not improve from 0.01725
# Epoch 36/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.1548 - binary_accuracy: 0.9971 - iou: 0.7373 - dice_coef: 0.8458 - val_loss: 0.1471 - val_binary_accuracy: 0.9973 - val_iou: 0.7457 - val_dice_coef: 0.8524
#
# Epoch 00036: val_iou did not improve from 0.01725
# Epoch 37/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.1517 - binary_accuracy: 0.9971 - iou: 0.7440 - dice_coef: 0.8486 - val_loss: 0.1390 - val_binary_accuracy: 0.9974 - val_iou: 0.7359 - val_dice_coef: 0.8311
#
# Epoch 00037: val_iou did not improve from 0.01725
# Epoch 38/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.1556 - binary_accuracy: 0.9970 - iou: 0.7380 - dice_coef: 0.8448 - val_loss: 0.1604 - val_binary_accuracy: 0.9971 - val_iou: 0.7317 - val_dice_coef: 0.8411
#
# Epoch 00038: val_iou did not improve from 0.01725
# Epoch 39/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.1570 - binary_accuracy: 0.9969 - iou: 0.7329 - dice_coef: 0.8413 - val_loss: 0.1377 - val_binary_accuracy: 0.9974 - val_iou: 0.7668 - val_dice_coef: 0.8626
#
# Epoch 00039: val_iou did not improve from 0.01725
# Epoch 40/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.1607 - binary_accuracy: 0.9969 - iou: 0.7284 - dice_coef: 0.8398 - val_loss: 0.1506 - val_binary_accuracy: 0.9972 - val_iou: 0.7312 - val_dice_coef: 0.8395
#
# Epoch 00040: val_iou did not improve from 0.01725
# Epoch 41/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.1519 - binary_accuracy: 0.9971 - iou: 0.7434 - dice_coef: 0.8481 - val_loss: 0.1389 - val_binary_accuracy: 0.9972 - val_iou: 0.7529 - val_dice_coef: 0.8546
#
# Epoch 00041: val_iou did not improve from 0.01725
# Epoch 42/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.1487 - binary_accuracy: 0.9972 - iou: 0.7468 - dice_coef: 0.8514 - val_loss: 0.1541 - val_binary_accuracy: 0.9971 - val_iou: 0.7434 - val_dice_coef: 0.8491
#
# Epoch 00042: val_iou did not improve from 0.01725
# Epoch 43/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.1573 - binary_accuracy: 0.9969 - iou: 0.7359 - dice_coef: 0.8432 - val_loss: 0.2684 - val_binary_accuracy: 0.9959 - val_iou: 0.5994 - val_dice_coef: 0.7370
#
# Epoch 00043: val_iou did not improve from 0.01725
# Epoch 44/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.1453 - binary_accuracy: 0.9972 - iou: 0.7535 - dice_coef: 0.8552 - val_loss: 0.1296 - val_binary_accuracy: 0.9974 - val_iou: 0.7789 - val_dice_coef: 0.8718
#
# Epoch 00044: val_iou did not improve from 0.01725
# Epoch 45/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.1454 - binary_accuracy: 0.9972 - iou: 0.7531 - dice_coef: 0.8550 - val_loss: 0.1463 - val_binary_accuracy: 0.9973 - val_iou: 0.7536 - val_dice_coef: 0.8565
#
# Epoch 00045: val_iou did not improve from 0.01725
# Epoch 46/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.1375 - binary_accuracy: 0.9973 - iou: 0.7634 - dice_coef: 0.8629 - val_loss: 0.1371 - val_binary_accuracy: 0.9975 - val_iou: 0.7683 - val_dice_coef: 0.8650
#
# Epoch 00046: val_iou did not improve from 0.01725
# Epoch 47/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.1358 - binary_accuracy: 0.9973 - iou: 0.7659 - dice_coef: 0.8642 - val_loss: 0.1400 - val_binary_accuracy: 0.9974 - val_iou: 0.7655 - val_dice_coef: 0.8635
#
# Epoch 00047: val_iou did not improve from 0.01725
# Epoch 48/70
# 88/88 [==============================] - 103s 1s/step - loss: 0.1381 - binary_accuracy: 0.9973 - iou: 0.7615 - dice_coef: 0.8612 - val_loss: 0.1227 - val_binary_accuracy: 0.9975 - val_iou: 0.7889 - val_dice_coef: 0.8800
#
# Epoch 00048: val_iou did not improve from 0.01725
# Epoch 49/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.1305 - binary_accuracy: 0.9974 - iou: 0.7725 - dice_coef: 0.8694 - val_loss: 0.1352 - val_binary_accuracy: 0.9975 - val_iou: 0.7422 - val_dice_coef: 0.8354
#
# Epoch 00049: val_iou did not improve from 0.01725
# Epoch 50/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.1356 - binary_accuracy: 0.9973 - iou: 0.7680 - dice_coef: 0.8647 - val_loss: 0.1920 - val_binary_accuracy: 0.9964 - val_iou: 0.6896 - val_dice_coef: 0.8110
#
# Epoch 00050: val_iou did not improve from 0.01725
# Epoch 51/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.1445 - binary_accuracy: 0.9972 - iou: 0.7532 - dice_coef: 0.8558 - val_loss: 0.1326 - val_binary_accuracy: 0.9975 - val_iou: 0.7722 - val_dice_coef: 0.8697
#
# Epoch 00051: val_iou did not improve from 0.01725
# Epoch 52/70
# 88/88 [==============================] - 101s 1s/step - loss: 0.1414 - binary_accuracy: 0.9973 - iou: 0.7620 - dice_coef: 0.8588 - val_loss: 0.1459 - val_binary_accuracy: 0.9973 - val_iou: 0.7451 - val_dice_coef: 0.8513
#
# Epoch 00052: val_iou did not improve from 0.01725
# Epoch 53/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.1362 - binary_accuracy: 0.9974 - iou: 0.7650 - dice_coef: 0.8620 - val_loss: 0.1302 - val_binary_accuracy: 0.9973 - val_iou: 0.7805 - val_dice_coef: 0.8727
#
# Epoch 00053: val_iou did not improve from 0.01725
# Epoch 54/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.1424 - binary_accuracy: 0.9973 - iou: 0.7577 - dice_coef: 0.8578 - val_loss: 0.1420 - val_binary_accuracy: 0.9973 - val_iou: 0.7622 - val_dice_coef: 0.8622
#
# Epoch 00054: val_iou did not improve from 0.01725
# Epoch 55/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.1362 - binary_accuracy: 0.9974 - iou: 0.7629 - dice_coef: 0.8617 - val_loss: 0.1276 - val_binary_accuracy: 0.9975 - val_iou: 0.7805 - val_dice_coef: 0.8749
#
# Epoch 00055: val_iou did not improve from 0.01725
# Epoch 56/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.1383 - binary_accuracy: 0.9974 - iou: 0.7650 - dice_coef: 0.8612 - val_loss: 0.1316 - val_binary_accuracy: 0.9977 - val_iou: 0.7780 - val_dice_coef: 0.8717
#
# Epoch 00056: val_iou did not improve from 0.01725
# Epoch 57/70
# 88/88 [==============================] - 103s 1s/step - loss: 0.1413 - binary_accuracy: 0.9973 - iou: 0.7611 - dice_coef: 0.8588 - val_loss: 0.1351 - val_binary_accuracy: 0.9973 - val_iou: 0.7476 - val_dice_coef: 0.8464
#
# Epoch 00057: val_iou did not improve from 0.01725
# Epoch 58/70
# 88/88 [==============================] - 103s 1s/step - loss: 0.1343 - binary_accuracy: 0.9974 - iou: 0.7684 - dice_coef: 0.8659 - val_loss: 0.1367 - val_binary_accuracy: 0.9973 - val_iou: 0.7685 - val_dice_coef: 0.8666
#
# Epoch 00058: val_iou did not improve from 0.01725
# Epoch 59/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.1295 - binary_accuracy: 0.9974 - iou: 0.7756 - dice_coef: 0.8708 - val_loss: 0.1446 - val_binary_accuracy: 0.9974 - val_iou: 0.7400 - val_dice_coef: 0.8460
#
# Epoch 00059: val_iou did not improve from 0.01725
# Epoch 60/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.1274 - binary_accuracy: 0.9975 - iou: 0.7784 - dice_coef: 0.8732 - val_loss: 0.1361 - val_binary_accuracy: 0.9973 - val_iou: 0.7592 - val_dice_coef: 0.8610
#
# Epoch 00060: val_iou did not improve from 0.01725
# Epoch 61/70
# 88/88 [==============================] - 101s 1s/step - loss: 0.1366 - binary_accuracy: 0.9973 - iou: 0.7645 - dice_coef: 0.8635 - val_loss: 0.2162 - val_binary_accuracy: 0.9963 - val_iou: 0.6631 - val_dice_coef: 0.7907
#
# Epoch 00061: val_iou did not improve from 0.01725
# Epoch 62/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.1708 - binary_accuracy: 0.9968 - iou: 0.7171 - dice_coef: 0.8286 - val_loss: 0.1375 - val_binary_accuracy: 0.9971 - val_iou: 0.7625 - val_dice_coef: 0.8637
#
# Epoch 00062: val_iou did not improve from 0.01725
# Epoch 63/70
# 88/88 [==============================] - 101s 1s/step - loss: 0.1387 - binary_accuracy: 0.9973 - iou: 0.7612 - dice_coef: 0.8617 - val_loss: 0.1440 - val_binary_accuracy: 0.9974 - val_iou: 0.7602 - val_dice_coef: 0.8574
#
# Epoch 00063: val_iou did not improve from 0.01725
# Epoch 64/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.1263 - binary_accuracy: 0.9975 - iou: 0.7772 - dice_coef: 0.8724 - val_loss: 0.1385 - val_binary_accuracy: 0.9976 - val_iou: 0.7638 - val_dice_coef: 0.8642
#
# Epoch 00064: val_iou did not improve from 0.01725
# Epoch 65/70
# 88/88 [==============================] - 101s 1s/step - loss: 0.1346 - binary_accuracy: 0.9975 - iou: 0.7696 - dice_coef: 0.8657 - val_loss: 0.1518 - val_binary_accuracy: 0.9971 - val_iou: 0.7319 - val_dice_coef: 0.8412
#
# Epoch 00065: val_iou did not improve from 0.01725
# Epoch 66/70
# 88/88 [==============================] - 100s 1s/step - loss: 0.1557 - binary_accuracy: 0.9970 - iou: 0.7367 - dice_coef: 0.8444 - val_loss: 0.1289 - val_binary_accuracy: 0.9975 - val_iou: 0.7775 - val_dice_coef: 0.8734
#
# Epoch 00066: val_iou did not improve from 0.01725
# Epoch 67/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.1325 - binary_accuracy: 0.9974 - iou: 0.7729 - dice_coef: 0.8679 - val_loss: 0.1400 - val_binary_accuracy: 0.9974 - val_iou: 0.7652 - val_dice_coef: 0.8632
#
# Epoch 00067: val_iou did not improve from 0.01725
# Epoch 68/70
# 88/88 [==============================] - 102s 1s/step - loss: 0.1229 - binary_accuracy: 0.9976 - iou: 0.7846 - dice_coef: 0.8775 - val_loss: 0.1263 - val_binary_accuracy: 0.9975 - val_iou: 0.7773 - val_dice_coef: 0.8731
#
# Epoch 00068: val_iou did not improve from 0.01725
# Epoch 69/70
# 88/88 [==============================] - 101s 1s/step - loss: 0.1260 - binary_accuracy: 0.9976 - iou: 0.7803 - dice_coef: 0.8737 - val_loss: 0.1285 - val_binary_accuracy: 0.9975 - val_iou: 0.7789 - val_dice_coef: 0.8731
#
# Epoch 00069: val_iou did not improve from 0.01725
# Epoch 70/70
# 88/88 [==============================] - 101s 1s/step - loss: 0.1423 - binary_accuracy: 0.9973 - iou: 0.7577 - dice_coef: 0.8579 - val_loss: 0.1375 - val_binary_accuracy: 0.9974 - val_iou: 0.7662 - val_dice_coef: 0.8656
#
# Epoch 00070: val_iou did not improve from 0.01725

# %%
# !mkdir -p saved_model
model.save('saved_model/my_model.h5')

# %%
# saving model achitecture in json file
model_json = model.to_json()
with open("UNet-seg-model.json", "w") as json_file:
    json_file.write(model_json)

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'binary_accuracy', 'iou', 'dice_coef', 'val_loss', 'val_binary_accuracy', 'val_iou', 'val_dice_coef'])

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['loss']);
plt.plot(history.history['val_loss']);
plt.title("Segmentation Loss");
plt.ylabel("Loss");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['binary_accuracy']);
plt.plot(history.history['val_binary_accuracy']);
plt.title("Segmentation Model binary_accuracy");
plt.ylabel("Binary Accuracy");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['iou']);
plt.plot(history.history['val_iou']);
plt.title("Segmentation Model IOU Loss");
plt.ylabel("IOU loss");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['dice_coef']);
plt.plot(history.history['val_dice_coef']);
plt.title("Segmentation Model Dice Loss");
plt.ylabel("Dice loss");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

# %%
test_ids = list(mri_test.img_path)
test_mask = list(mri_test.mask_path)

# %%
def prediction(test, model_seg):
  
    # empty list to store results
    mask, image_id,has_mask = [], [], []
    
    #itetrating through each image in test data
    for i in test.img_path:
        

        
        #Creating a empty array of shape 1,256,256,1
        X = np.empty((1,256,256,3))
        # read the image
        img = io.imread(i)
        #resizing the image and coverting them to array of type float64
        img = cv2.resize(img, (256,256))
        img = np.array(img, dtype=np.float64)
        
        # standardising the image
        img -= img.mean()
        img /= img.std()
        #converting the shape of image from 256,256,3 to 1,256,256,3
        X[0,] = img
        
        #make prediction of mask
        predict = model_seg.predict(X)
        
        # if sum of predicted mask is 0 then there is not tumour
        if predict.round().astype(int).sum()==0:
            image_id.append(i)
            has_mask.append(0)
            mask.append('No mask :)')
        else:
        #if the sum of pixel values are more than 0, then there is tumour
            image_id.append(i)
            has_mask.append(1)
            mask.append(predict)
            
    return pd.DataFrame({'img_path': image_id,'predicted_mask': mask,'has_mask': has_mask})

# %%
df_pred = prediction(mri_test, model)
df_pred
# Out:
#                                               img_path  \
# 0    /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1    /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2    /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3    /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4    /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# ..                                                 ...
# 388  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 389  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 390  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 391  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 392  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#                                         predicted_mask  has_mask
# 0    [[[[2.8321341e-05], [1.0489813e-05], [8.199317...         1
# 1                                           No mask :)         0
# 2    [[[[2.2603397e-05], [1.0081533e-05], [8.199317...         1
# 3                                           No mask :)         0
# 4                                           No mask :)         0
# ..                                                 ...       ...
# 388                                         No mask :)         0
# 389                                         No mask :)         0
# 390  [[[[3.030634e-05], [1.0615658e-05], [8.199317e...         1
# 391  [[[[4.0827166e-05], [1.11873915e-05], [8.19931...         1
# 392  [[[[2.8643808e-05], [1.0510742e-05], [8.199317...         1
#
# [393 rows x 3 columns]

# %%
df_pred = mri_test.merge(df_pred, on='img_path')
df_pred.head()
# Out:
#                                             img_path  \
# 0  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#                                            mask_path  mask  \
# 0  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     1
# 1  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 2  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     1
# 3  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 4  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
#
#                                       predicted_mask  has_mask
# 0  [[[[2.8321341e-05], [1.0489813e-05], [8.199317...         1
# 1                                         No mask :)         0
# 2  [[[[2.2603397e-05], [1.0081533e-05], [8.199317...         1
# 3                                         No mask :)         0
# 4                                         No mask :)         0

# %%
count = 0
fig, axs = plt.subplots(3,5, figsize=(30,15))

for i in range(len(df_pred)):
    if df_pred.has_mask[i]==1 and count<15:
        #read mri images
        img = io.imread(df_pred.img_path[i])
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        axs[count][0].imshow(img)
        axs[count][0].title.set_text('Brain MRI')
        
        #read original mask
        mask = io.imread(df_pred.mask_path[i])
        axs[count][1].imshow(mask)
        axs[count][1].title.set_text('Ground Truth')
        
        #read predicted mask
        pred = np.array(df_pred.predicted_mask[i]).squeeze().round()
        axs[count][2].imshow(pred)
        axs[count][2].title.set_text('predicted mask')
        
        #overlay original mask with MRI
        img[mask==255] = (255,0,0)
        axs[count][3].imshow(img)
        axs[count][3].title.set_text('Brain MRI with original mask (Ground Truth)')
        
        #overlay predicted mask and MRI
        img_ = io.imread(df_pred.img_path[i])
        img_ = cv2.cvtColor(img_, cv2.COLOR_BGR2RGB)
        img_[pred==1] = (0,255,150)
        axs[count][4].imshow(img_)
        axs[count][4].title.set_text('MRI with PREDICTED MASK')
        
        count +=1
    if (count==3):
        break

fig.tight_layout()
